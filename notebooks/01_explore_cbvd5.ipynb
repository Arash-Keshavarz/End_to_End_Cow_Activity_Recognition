# %%
import os
import glob
import json
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = (10, 6)

DATA_ROOT = Path("../data/CBVD-5")

# %% [markdown]
# ## Load few videos
